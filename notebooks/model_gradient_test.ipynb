# %% [markdown]
# ## Model Gradient Test
#
# By: Rebecca Gjini
#
# About: This notebook will cover testing taking the gradient over the entire SpeedyModel.
#
# Notes:
# 1) Shape of the output state goes from 3 dimensions to 4, with an extra dimension added to the beginning (of size 0)
# 2) sim_time in the dinosaur object in the preditions dictionary object is empty in the model output
# 3) lfluxland and date.tyear are also empty arrays in the predictions dictionary object (not sure exactly why) and this makes our PhysicsData ones object not work as the input to the gradient function

# %%
from jcm.model import SpeedyModel
import jax
import jax.numpy as jnp
from dinosaur import primitive_equations
from jcm.physics_data import PhysicsData
from jcm.params import Parameters

jax.config.update('jax_disable_jit', False) # Turn off JIT because of an issue in shortwave_radiation.py:169
jax.config.update("jax_debug_infs", True) # doesn't add any time since the saved time is otherwise spent getting the nodal quantities
jax.config.update("jax_debug_nans", False) # some physics fields might be nan

# %%
# Create moodel object and test to make sure running the model works
model = SpeedyModel(time_step=30, save_interval=(1.0/48.0), total_time=(1.0/24.0), layers=8) # takes 40 seconds on laptop gpu
state = model.get_initial_state()
final_state, predictions = model.unroll(state)
print(type(final_state))
print(type(predictions))
print(primitive_equations.validate_state_shape(final_state, model.coords))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       2 model = SpeedyModel(time_step=30, save_interval=(1.0/48.0), total_time=(1.0/24.0), layers=8) # takes 40 seconds on laptop gpu
#       3 state = model.get_initial_state()
# ----> 4 final_state, predictions = model.unroll(state)
#       5 print(type(final_state))
#       6 print(type(predictions))
#
# File ~/Desktop/NeuralGCM_Jax/jax-gcm/jcm/model.py:234, in SpeedyModel.unroll(self, state)
#     226 def unroll(self, state: dinosaur.primitive_equations.StateWithTime) -> tuple[dinosaur.primitive_equations.StateWithTime, dinosaur.primitive_equations.StateWithTime]:
#     227     integrate_fn = jax.jit(dinosaur.time_integration.trajectory_from_step(
#     228         self.step_fn,
#     229         outer_steps=self.outer_steps,
#    (...)
#     232         post_process_fn=self.post_process,
#     233     ))
# --> 234     return integrate_fn(state)
#
#     [... skipping hidden 13 frame]
#
# File ~/opt/anaconda3/envs/jcm/lib/python3.13/site-packages/dinosaur/time_integration.py:667, in trajectory_from_step.<locals>.multistep(x)
#     666 def multistep(x):
# --> 667   return outer_scan_fn(step, x, xs=None, length=outer_steps)
#
#     [... skipping hidden 9 frame]
#
# File ~/opt/anaconda3/envs/jcm/lib/python3.13/site-packages/dinosaur/time_integration.py:662, in trajectory_from_step.<locals>.step(carry_in, _)
#     661 def step(carry_in, _):
# --> 662   carry_out = step_fn(carry_in)
#     663   frame = carry_in if start_with_input else carry_out
#     664   return carry_out, post_process_fn(frame)
#
# File ~/opt/anaconda3/envs/jcm/lib/python3.13/site-packages/dinosaur/time_integration.py:623, in repeated.<locals>.f_repeated(x_initial)
#     621 def f_repeated(x_initial: PyTreeState) -> PyTreeState:
#     622   g = lambda x, _: (fn(x), None)
# --> 623   x_final, _ = scan_fn(g, x_initial, xs=None, length=steps)
#     624   return x_final
#
#     [... skipping hidden 9 frame]
#
# File ~/opt/anaconda3/envs/jcm/lib/python3.13/site-packages/dinosaur/time_integration.py:622, in repeated.<locals>.f_repeated.<locals>.<lambda>(x, _)
#     621 def f_repeated(x_initial: PyTreeState) -> PyTreeState:
# --> 622   g = lambda x, _: (fn(x), None)
#     623   x_final, _ = scan_fn(g, x_initial, xs=None, length=steps)
#     624   return x_final
#
# File ~/opt/anaconda3/envs/jcm/lib/python3.13/site-packages/dinosaur/time_integration.py:605, in step_with_filters.<locals>._step_fn(u)
#     604 def _step_fn(u: PyTreeState) -> PyTreeState:
# --> 605   u_next = step_fn(u)
#     606   for filter_fn in filters:
#     607     u_next = filter_fn(u, u_next)
#
# File ~/opt/anaconda3/envs/jcm/lib/python3.13/site-packages/tree_math/_src/func_wrappers.py:55, in wrap.<locals>.wrapper(*args, **kwargs)
#      53 args = _apply_argnums(vector.Vector, args, vector_argnums)
#      54 kwargs = _apply_argnames(vector.Vector, kwargs, vector_argnames)
# ---> 55 result = fun(*args, **kwargs)
#      56 return tree_util.tree_map(_maybe_get_tree, result, is_leaf=_is_vector)
#
# File ~/opt/anaconda3/envs/jcm/lib/python3.13/site-packages/dinosaur/time_integration.py:389, in imex_runge_kutta.<locals>.step_fn(y0)
#     386 f = [None] * num_steps
#     387 g = [None] * num_steps
# --> 389 f[0] = F(y0)
#     390 g[0] = G(y0)
#     392 for i in range(1, num_steps):
#
# File ~/opt/anaconda3/envs/jcm/lib/python3.13/site-packages/tree_math/_src/func_wrappers.py:76, in unwrap.<locals>.wrapper(*args, **kwargs)
#      74 args = _apply_argnums(_get_tree, args, vector_argnums)
#      75 kwargs = _apply_argnames(_get_tree, kwargs, vector_argnames)
# ---> 76 result = fun(*args, **kwargs)
#      77 return tree_util.tree_map(_maybe_vector, out_vectors, result)
#
# File ~/opt/anaconda3/envs/jcm/lib/python3.13/site-packages/dinosaur/time_integration.py:153, in compose_equations.<locals>.explicit_fn(x)
#     152 def explicit_fn(x: PyTreeState) -> PyTreeState:
# --> 153   explicit_tendencies = [fn.explicit_terms(x) for fn in equations]
#     154   return tree_map(
#     155       lambda *args: sum([x for x in args if x is not None]),
#     156       *explicit_tendencies)
#
# File ~/Desktop/NeuralGCM_Jax/jax-gcm/jcm/model.py:71, in convert_tendencies_to_equation.<locals>.physical_tendencies(state)
#      59 date = DateData.set_date(
#      60     model_time = reference_date + Timedelta(
#      61         seconds=dynamics.physics_specs.dimensionalize(state.sim_time, units.second).m
#      62     )
#      63 )
#      65 data = PhysicsData.zeros(
#      66     dynamics.coords.nodal_shape[1:],
#      67     dynamics.coords.nodal_shape[0],
#      68     date=date
#      69 )
# ---> 71 return get_physical_tendencies(state=state, dynamics=dynamics, time_step=time_step, physics_terms=physics_terms, boundaries=boundaries, parameters=parameters, data=data)
#
# File ~/Desktop/NeuralGCM_Jax/jax-gcm/jcm/physics.py:217, in get_physical_tendencies(state, dynamics, time_step, physics_terms, boundaries, parameters, data)
#     197 def get_physical_tendencies(
#     198     state: StateWithTime,
#     199     dynamics: PrimitiveEquations,
#    (...)
#     204     data: PhysicsData = None
#     205 ):
#     206     """
#     207     Computes the physical tendencies given the current state and a list of physics functions.
#     208
#    (...)
#     215         Physical tendencies
#     216     """
# --> 217     physics_state = dynamics_state_to_physics_state(state, dynamics)
#     219     # the 'physics_terms' return an instance of tendencies and data, data gets overwritten at each step
#     220     # and implicitly passed to the next physics_term. tendencies are summed
#     221     physics_tendency = PhysicsTendency.zeros(shape=physics_state.u_wind.shape)
#
# File ~/Desktop/NeuralGCM_Jax/jax-gcm/jcm/physics.py:136, in dynamics_state_to_physics_state(state, dynamics)
#     133 t = nodal_state.temperature_variation
#     134 q = nodal_state.tracers['specific_humidity']
# --> 136 phi_spectral = get_geopotential(
#     137     state.temperature_variation,
#     138     dynamics.reference_temperature,
#     139     dynamics.orography,
#     140     dynamics.coords.vertical,
#     141 )
#     142 phi = dynamics.coords.horizontal.to_nodal(phi_spectral)
#     143 log_sp = dynamics.coords.horizontal.to_nodal(state.log_surface_pressure)
#
# TypeError: get_geopotential() missing 2 required positional arguments: 'gravity_acceleration' and 'ideal_gas_constant'

# %%
print(predictions.keys())
print(type(predictions['dynamics']))
print(type(predictions['physics']))
# Out:
# dict_keys(['dynamics', 'physics'])
# <class 'dinosaur.primitive_equations.State'>
# <class 'jcm.physics_data.PhysicsData'>

# %%
# Functions to create ones objects to feed into the jax gradient function
def make_ones_dinosaur_StateWithTime_object(state, choose_sim_time = jnp.float32(1.0)):
    vorticity = jnp.ones_like(state.vorticity)
    divergence = jnp.ones_like(state.divergence)
    temperature_variation = jnp.ones_like(state.temperature_variation)
    log_surface_pressure = jnp.ones_like(state.log_surface_pressure)
    tracers = {'specific_humidity' : jnp.ones_like(state.tracers['specific_humidity'])}
    sim_time = choose_sim_time
    return primitive_equations.StateWithTime(vorticity = vorticity, divergence = divergence,
                                             temperature_variation = temperature_variation,
                                             log_surface_pressure = log_surface_pressure,
                                             tracers = tracers, sim_time = sim_time)

def make_ones_prediction_object(pred): 
    (additional, ix, il, kx) = pred['physics'].shortwave_rad.dfabs.shape
    physics_data = PhysicsData.ones((additional, ix, il), kx)
    physics_data.mod_radcon.ablco2 = jnp.array([])
    physics_data.date.tyear = jnp.array([])
    physics_data.date.model_year = jnp.array([])
    return{'dynamics': make_ones_dinosaur_StateWithTime_object(pred['dynamics'], jnp.array([])), 
           'physics' : physics_data}

# %%
# Call to vjp to create gradient function and model output
primals, f_vjp = jax.vjp(model.unroll, state)

# %%
# Calculate gradient with respect to the state
input = (make_ones_dinosaur_StateWithTime_object(primals[0]), make_ones_prediction_object(primals[1]))
df_dstate = f_vjp(input)

# %%
print('Is the vorticity nan?', jnp.any(jnp.isnan(df_dstate[0].vorticity)))
print('Is the divergence nan?', jnp.any(jnp.isnan(df_dstate[0].divergence)))
print('Is the temperature variation nan?', jnp.any(jnp.isnan(df_dstate[0].temperature_variation)))
print('Is the log surcafe pressure nan?', jnp.any(jnp.isnan(df_dstate[0].log_surface_pressure)))
# Out:
# Is the vorticity nan? False
# Is the divergence nan? False
# Is the temperature variation nan? False
# Is the log surcafe pressure nan? False

# %%
print(type(df_dstate[0].tracers))
print(df_dstate[0].tracers.keys())
print('Is the specific humidity nan?', jnp.any(jnp.isnan(df_dstate[0].tracers['specific_humidity'])))
# Out:
# <class 'dict'>
# dict_keys(['specific_humidity'])
# Is the specific humidity nan? False

# %%
print('Is the simulation time nan?', jnp.any(jnp.isnan(df_dstate[0].sim_time)))
# Out:
# Is the simulation time nan? False

# %% [markdown]
# ### This next part of the notebook is to test the gradients with respect to the parameters

# %%
# Create function to run the forward model with respect to that parameters
def run_model_wrt_parameters(parameters):
    model = SpeedyModel(time_step=30, save_interval=0.1, total_time=(10.0/48.0), layers=8, 
                        parameters = parameters
    )
    state = model.get_initial_state()   
    final_state, predictions = model.unroll(state)
    return predictions

# %%
# Set parameters object using the defualt parameter values
parameters = Parameters.default()

# %%
# Taking thr gradient with respect to the default parameters
jcm_primals, grad_jcm = jax.vjp(run_model_wrt_parameters, parameters)

# %%
input = (make_ones_prediction_object(jcm_primals))
df_dparameters = grad_jcm(input)
